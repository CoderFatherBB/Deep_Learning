# %%
# !nvidia-smi
# Out:
# Mon Apr 22 12:51:42 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 552.22                 Driver Version: 552.22         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   45C    P0             23W /  140W |       0MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.44  Python-3.8.19 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Setup complete  (20 CPUs, 15.7 GB RAM, 246.4/450.1 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=SKF_Dataset/data.yaml epochs=50 imgsz=640 plots=True

# %%
Image(filename=f'runs/detect/train/confusion_matrix.png')

# %%
Image(filename=f'runs/detect/train/results.png')

# %%
Image(filename=f'runs/detect/train/val_batch0_pred.jpg')

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=bottle_cap_dataset/data.yaml
